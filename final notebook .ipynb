# %% [markdown]
# # Final Notebook

# %%
# !pip install nbmerge
# Out:
# Requirement already satisfied: nbmerge in /opt/anaconda3/lib/python3.13/site-packages (0.0.4)

# %% [markdown]
# # Merging all DataFrames

# %%
# !nbmerge "Yahoo Finance.ipynb" \
         "FRED.ipynb" \
         "GHG:Carbon Emissions.ipynb" \
         "Market Risk Premium.ipynb" \
         "Data Alignment and Merging.ipynb" \
         -o "final_notebook.ipynb"
# Merging all DataFrames 
import os
print(os.listdir())
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/nbformat/__init__.py:132: DuplicateCellId: Non-unique cell id 'f1085a64-6fd3-4164-a2cb-c8ae6b4ee666' detected. Corrected to '2dd6ca19'.
#   validate(nb)
# /opt/anaconda3/lib/python3.13/site-packages/nbformat/__init__.py:132: DuplicateCellId: Non-unique cell id 'f1085a64-6fd3-4164-a2cb-c8ae6b4ee666' detected. Corrected to '4d2d57de'.
#   validate(nb)
# /opt/anaconda3/lib/python3.13/site-packages/nbformat/__init__.py:132: DuplicateCellId: Non-unique cell id 'f1085a64-6fd3-4164-a2cb-c8ae6b4ee666' detected. Corrected to '52a9d2ac'.
#   validate(nb)
# /opt/anaconda3/lib/python3.13/site-packages/nbformat/__init__.py:132: DuplicateCellId: Non-unique cell id 'f1085a64-6fd3-4164-a2cb-c8ae6b4ee666' detected. Corrected to '6340fda9'.
#   validate(nb)
# ['aligned_data.csv', 'final_notebook.ipynb', '.DS_Store', 'cleaned_market_risk_premium.csv', 'final notebook .ipynb', 'FRED.ipynb', 'rf_daily.csv', 'Market Risk Premium.ipynb', 'basket_metrics.csv', 'Yahoo Finance.ipynb', 'GHG:Carbon Emissions.ipynb', 'daily_returns.csv', 'Data Alignment and Merging.ipynb', 'ghg_macro.csv']
